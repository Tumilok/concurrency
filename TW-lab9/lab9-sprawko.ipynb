# %% [markdown]
# # JCSP - Sprawozdanie

# %% [markdown]
# ### Producent i konsument

# %%
from matplotlib import pyplot as plt

plt.plot([1, 2, 3, 5, 10, 20, 35, 50, 75, 100], [2310012895, 1654821674, 1661522063, 1665535055, 1607587060, 1757722793, 1725489522, 1768033893, 1992649579, 1778499533], label='producer unordered')
plt.plot([1, 2, 3, 5, 10, 20, 35, 50, 75, 100], [1556356082, 1632602093, 1637289227, 2150515755, 2943932051, 5534395295, 7515314335, 9369435147, 14085531408, 17699928854], label='producer ordered')
plt.legend()

# %%
from matplotlib import pyplot as plt

plt.plot([1, 2, 3, 5, 10, 20, 35, 50, 75, 100], [2309949983, 1654661023, 1661438184, 1664758891, 1607491463, 1757114085, 1721436388, 1767346844, 1992180945, 1778457104], label='consumer unordered')
plt.plot([1, 2, 3, 5, 10, 20, 35, 50, 75, 100], [1556265684, 1632445761, 1636375200, 2139116865, 2938224568, 5534828368, 7520025875, 9369970886, 14090296615, 17724042373], label='consumer ordered')
plt.legend()
