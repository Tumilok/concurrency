# %%
import pandas as pd

data = pd.read_csv("result.csv")

data
# Out:
#      Buff_size Prod_or_cons  Size  PC_config  Is_fair Randomization  \
# 0        10000     Consumer  2048        100     True          fair
# 1        10000     Consumer    64        100     True          fair
# 2        10000     Consumer  1024        100     True          fair
# 3        10000     Consumer    32        100     True          fair
# 4        10000     Consumer   512        100     True          fair
# ..         ...          ...   ...        ...      ...           ...
# 295     100000     Consumer     8       1000    False        unfair
# 296     100000     Producer     1       1000    False        unfair
# 297     100000     Producer     2       1000    False        unfair
# 298     100000     Producer     4       1000    False        unfair
# 299     100000     Producer     8       1000    False        unfair
#
#      Buff_access_num
# 0             651618
# 1             651314
# 2             650025
# 3             650579
# 4             649591
# ...

# %%
grouped = data.groupby(['Buff_size', 'Prod_or_cons', 'PC_config', 'Is_fair', 'Randomization'])

grouped.count()
# Out:
#                                                         Size  Buff_access_num
# Buff_size Prod_or_cons PC_config Is_fair Randomization
# 10000     Consumer     100       False   fair             13               13
#                                          unfair            4                4
#                                  True    fair             13               13
#                                          unfair            4                4
#                        1000      False   fair             13               13
#                                          unfair            4                4
#                                  True    fair             13               13
#                                          unfair            4                4
#           Producer     100       False   fair             13               13
#                                          unfair            4                4
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)

def draw_plot(data):
    x = []
    y = []
    for i,j in data.items():
        x.append(str(i))
        y.append(j)
    plt.scatter(x,y)
    plt.show()
    
def f():
    for group,data_for_group in grouped:
        print(group)
        print(f"Buffer size is {group[0]}, {group[1]}, number of {group[1]}s is {group[2]}, normal randomization: {group[4]}, fair buffer: {group[3]}")
        print(group)
        a = data_for_group.groupby("Size")["Buff_access_num"].sum()
        a.plot.box()
        yield plt.show()
        print()
        
        yield draw_plot(a)

# %%
iterator = f()
next(iterator)
next(iterator)
next(iterator)
next(iterator)
# Out:
# (10000, 'Consumer', 100, False, 'fair')
# Buffer size is 10000, Consumer, number of Consumers is 100, normal randomization: fair, fair buffer: False
# (10000, 'Consumer', 100, False, 'fair')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-270-321905afe600> in <module>
#       1 iterator = f()
#       2 next(iterator)
# ----> 3 next(iterator)
#       4 next(iterator)
#       5 next(iterator)
#
# <ipython-input-269-a91e0dc2d462> in f()
#      21         print()
#      22
# ---> 23         yield draw_plot(a)
#
# TypeError: draw_plot() missing 1 required positional argument: 'data'

# %%
next(iterator)
next(iterator)
next(iterator)
next(iterator)
# Out:
# Buffer size is 10000, Consumer, number of Consumers is 1000, is fair buffer: False, randomization: fair
# Buffer size is 10000, Consumer, number of Consumers is 1000, is fair buffer: False, randomization: unfair
# Buffer size is 10000, Consumer, number of Consumers is 1000, is fair buffer: True, randomization: fair
# Buffer size is 10000, Consumer, number of Consumers is 1000, is fair buffer: True, randomization: unfair

# %%
next(iterator)
next(iterator)
next(iterator)
next(iterator)
# Out:
# Buffer size is 10000, Producer, number of Producers is 100, is fair buffer: False, randomization: fair
# Buffer size is 10000, Producer, number of Producers is 100, is fair buffer: False, randomization: unfair
# Buffer size is 10000, Producer, number of Producers is 100, is fair buffer: True, randomization: fair
# Buffer size is 10000, Producer, number of Producers is 100, is fair buffer: True, randomization: unfair

# %%
next(iterator)
next(iterator)
next(iterator)
next(iterator)
# Out:
# Buffer size is 10000, Producer, number of Producers is 1000, is fair buffer: False, randomization: fair
# Buffer size is 10000, Producer, number of Producers is 1000, is fair buffer: False, randomization: unfair
# Buffer size is 10000, Producer, number of Producers is 1000, is fair buffer: True, randomization: fair
# Buffer size is 10000, Producer, number of Producers is 1000, is fair buffer: True, randomization: unfair

# %%
next(iterator)
next(iterator)
next(iterator)
next(iterator)
# Out:
# Buffer size is 100000, Consumer, number of Consumers is 100, is fair buffer: False, randomization: fair
# Buffer size is 100000, Consumer, number of Consumers is 100, is fair buffer: False, randomization: unfair
# Buffer size is 100000, Consumer, number of Consumers is 100, is fair buffer: True, randomization: fair
# Buffer size is 100000, Consumer, number of Consumers is 100, is fair buffer: True, randomization: unfair

# %%
next(iterator)
next(iterator)
next(iterator)
next(iterator)
# Out:
# Buffer size is 100000, Consumer, number of Consumers is 1000, is fair buffer: False, randomization: fair
# Buffer size is 100000, Consumer, number of Consumers is 1000, is fair buffer: False, randomization: unfair
# Buffer size is 100000, Consumer, number of Consumers is 1000, is fair buffer: True, randomization: fair
# Buffer size is 100000, Consumer, number of Consumers is 1000, is fair buffer: True, randomization: unfair

# %%
next(iterator)
next(iterator)
next(iterator)
next(iterator)
# Out:
# Buffer size is 100000, Producer, number of Producers is 100, is fair buffer: False, randomization: fair
# Buffer size is 100000, Producer, number of Producers is 100, is fair buffer: False, randomization: unfair
# Buffer size is 100000, Producer, number of Producers is 100, is fair buffer: True, randomization: fair
# Buffer size is 100000, Producer, number of Producers is 100, is fair buffer: True, randomization: unfair

# %%
next(iterator)
next(iterator)
next(iterator)
next(iterator)
# Out:
# Buffer size is 100000, Producer, number of Producers is 1000, is fair buffer: False, randomization: fair
# Buffer size is 100000, Producer, number of Producers is 1000, is fair buffer: False, randomization: unfair
# Buffer size is 100000, Producer, number of Producers is 1000, is fair buffer: True, randomization: fair
# Buffer size is 100000, Producer, number of Producers is 1000, is fair buffer: True, randomization: unfair
