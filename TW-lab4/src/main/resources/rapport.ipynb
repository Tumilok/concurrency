# %%
import pandas as pd

data = pd.read_csv("result.csv")

data
# Out:
#      Buff_size Prod_or_cons  Size  PC_config  Is_fair Randomization  \
# 0        10000     Consumer  2048        100     True          fair
# 1        10000     Consumer    64        100     True          fair
# 2        10000     Consumer  1024        100     True          fair
# 3        10000     Consumer    32        100     True          fair
# 4        10000     Consumer   512        100     True          fair
# ..         ...          ...   ...        ...      ...           ...
# 295     100000     Consumer     8       1000    False        unfair
# 296     100000     Producer     1       1000    False        unfair
# 297     100000     Producer     2       1000    False        unfair
# 298     100000     Producer     4       1000    False        unfair
# 299     100000     Producer     8       1000    False        unfair
#
#      Buff_access_num
# 0             651618
# 1             651314
# 2             650025
# 3             650579
# 4             649591
# ...

# %%
grouped = data.groupby(['Buff_size', 'Prod_or_cons', 'PC_config', 'Is_fair', 'Randomization'])

grouped.count()
# Out:
#                                                         Size  Buff_access_num
# Buff_size Prod_or_cons PC_config Is_fair Randomization
# 10000     Consumer     100       False   fair             13               13
#                                          unfair            4                4
#                                  True    fair             13               13
#                                          unfair            4                4
#                        1000      False   fair             13               13
#                                          unfair            4                4
#                                  True    fair             13               13
#                                          unfair            4                4
#           Producer     100       False   fair             13               13
#                                          unfair            4                4
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)


def draw_plot(data):
    x = []
    y = []
    for i, j in data.items():
        x.append(str(i))
        y.append(j)
        
    plt.scatter(x, y)
    plt.xlabel('Portion size')
    plt.ylabel('Buffer access number')
    plt.show()

    
def get_iterator():
    for grouped_by, grouped_data in grouped:
        print(f"Buffer size: {grouped_by[0]}, Worker: {grouped_by[1]}, Worker number: {grouped_by[2]}, Is fair buffer: {grouped_by[3]}, Randomization type: {grouped_by[4]}")
        data_to_show = grouped_data.groupby("Size")["Buff_access_num"].sum()
        
        data_to_show.plot.box()
        print(plt.show())
        print()
        print(draw_plot(data_to_show))
        
iterator = get_iterator()
# Out:
# Buffer size: 10000, Worker: Consumer, Worker number: 100, Is fair buffer: False, Randomization type: fair
# None
# None
# Buffer size: 10000, Worker: Consumer, Worker number: 100, Is fair buffer: False, Randomization type: unfair
# None
# None
# Buffer size: 10000, Worker: Consumer, Worker number: 100, Is fair buffer: True, Randomization type: fair
# None
# None
# Buffer size: 10000, Worker: Consumer, Worker number: 100, Is fair buffer: True, Randomization type: unfair
# None
# None
# Buffer size: 10000, Worker: Consumer, Worker number: 1000, Is fair buffer: False, Randomization type: fair
# None
# None
# Buffer size: 10000, Worker: Consumer, Worker number: 1000, Is fair buffer: False, Randomization type: unfair
# None
# None
# Buffer size: 10000, Worker: Consumer, Worker number: 1000, Is fair buffer: True, Randomization type: fair
# None
# None
# Buffer size: 10000, Worker: Consumer, Worker number: 1000, Is fair buffer: True, Randomization type: unfair
# None
# None
# ...
